# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/Rating_Survey_preferences_people.csv")
data.head()
# Out:
#                         Timestamp                     Username Age  Gender  \
# 0  2023/10/04 1:17:44 PM GMT+5:30  aakashshingadia45@gmail.com  41    Male
# 1  2023/10/04 1:20:00 PM GMT+5:30  sketchofficial028@gmail.com  22    Male
# 2  2023/10/04 1:20:20 PM GMT+5:30  bhaveshradiya1230@gmail.com  43  Female
# 3  2023/10/04 1:21:11 PM GMT+5:30  aakashshingadia45@gmail.com  38  Female
# 4  2023/10/04 1:23:25 PM GMT+5:30     modhakashyap22@gmail.com  56    Male
#
#     Height   Weight                                     Work Crieteria  \
# 0     5'7"       70  Moderately active: moderate exercise/sports 3-...
# 1    6fits       55  Light activity: light exercise/sports 1-3 days...
# 2  149.9cm  51.09kg                   Sedentary: little or no exercise
# 3     5'4"       68  Light activity: light exercise/sports 1-3 days...
# 4      5'2       60  Light activity: light exercise/sports 1-3 days...
#
#                                            Main Meal  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 37 columns):
#  #   Column                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                  --------------  -----
#  0   Timestamp                                                                                               375 non-null    object
#  1   Username                                                                                                375 non-null    object
#  2   Age                                                                                                     375 non-null    object
#  3   Gender                                                                                                  375 non-null    object
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Username', 'Age', 'Gender', 'Height', 'Weight',
#        'Work Crieteria', 'Main Meal',
#        'Rating Of  Selected Items of  Main Meal [Selected Food]',
#        'NUTRITIVE VALUE FOR (SNACK)',
#        'Rating Of  Selected Items of  NUTRITIVE VALUE FOR (SNACK) [Selected Food]',
#        'NUTRITIVE VALUE FOR (MAIN MEAL) DAL & SUBJI (COUNTED \r\nTHE NUTRITIVE VALUE FOR 1 BOWL)   ',
#        'Rating Of Selected Item of    NUTRITIVE VALUE FOR (MAIN MEAL) DAL & SUBJI  [Selected Food]',
#        'NUTRITIVE VALUE FOR (SNACKS)  ',
#        'Rating Of Selected Item of  NUTRITIVE VALUE FOR (SNACKS)   [Selected Food]',
#        'NUTRITIVE VALUE FOR (LEAFY VEGETABLES) (1 SMALL BOWL)  ',
#        'Rating Of Selected Item of    NUTRITIVE VALUE FOR (LEAFY VEGETABLES)  [Selected Food]',
#        'NUTRITIVE VALUE FOR (OTHER VEGETABLES) (1 SMALL BOWL)  ',
#        'Rating Of Selected Item Of   NUTRITIVE VALUE FOR (OTHER VEGETABLES)  [Selected Food]',
# ...

# %%
data.iloc[0:1]
# Out:
#                         Timestamp                     Username Age Gender  \
# 0  2023/10/04 1:17:44 PM GMT+5:30  aakashshingadia45@gmail.com  41   Male
#
#   Height Weight                                     Work Crieteria  \
# 0   5'7"     70  Moderately active: moderate exercise/sports 3-...
#
#                                            Main Meal  \
# 0  Rotla (Bajra)(1 Medium Size) Proteins= 3.65  ,...
#
#    Rating Of  Selected Items of  Main Meal [Selected Food]  \
# 0                                                  9
#
#                          NUTRITIVE VALUE FOR (SNACK)  ...  \
# 0  Khakhra(1 Pieces) (1 Medium Size)  Proteins=3....  ...
#
#    NUTRITIVE VALUE FOR (PULSE + VEGETABLE PRODUCT) (1 SMALL BOWL)    \
# 0  Undhiyu(1 Small Bowl)  Proteins = 6.8  Carbs=1...
#
#   Rating Of  Selected Item Of  NUTRITIVE VALUE FOR (PULSE + VEGETABLE PRODUCT) [Selected Food]  \
# 0                                                  9
#
# ...

# %%
data.drop(['Timestamp','Username','Height'],axis=1 , inplace=True)

# %%
data.sample(1)
# Out:
#     Age  Gender Weight                    Work Crieteria  \
# 306  64  Female     73  Sedentary: little or no exercise
#
#                                              Main Meal  \
# 306  Paratha(1 Medium Size) Proteins=  4.25 , Carbs...
#
#      Rating Of  Selected Items of  Main Meal [Selected Food]  \
# 306                                                  9
#
#                            NUTRITIVE VALUE FOR (SNACK)  \
# 306  Khakhra(1 Pieces) (1 Medium Size)  Proteins=3....
#
#      Rating Of  Selected Items of  NUTRITIVE VALUE FOR (SNACK) [Selected Food]  \
# 306                                                 10
#
#     NUTRITIVE VALUE FOR (MAIN MEAL) DAL & SUBJI (COUNTED \r\nTHE NUTRITIVE VALUE FOR 1 BOWL)     \
# 306  Green gram subji(1 Small Bowl) Proteins= 5.95 ...
#
#      Rating Of Selected Item of    NUTRITIVE VALUE FOR (MAIN MEAL) DAL & SUBJI  [Selected Food]  \
# 306                                               10.0
#
# ...

# %%
data['Age']
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 375 entries, 0 to 374
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 375 non-null    object
# dtypes: object(1)
# memory usage: 3.1+ KB
