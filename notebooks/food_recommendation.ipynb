# %%
import pandas as pd

# %%
# Specify the path to your Excel file
excel_file_path = '/workspaces/codespaces-blank/data/FOOD_DATA.xlsx'

# %%
# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file_path)

# Display the DataFrame
print(df)
# Out:
#     FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                              Table 1
# 3                      NUTRITIVE VALUE FOR (MAIN MEAL)
# 4                                            Sr. \nNo.
# ..                                                 ...
# 151                                                 26
# 152                                                 27
# 153                                                 28
# 154                                                 29
# 155                                                 30
#
#                           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                NaN        NaN        NaN        NaN
# 1                                NaN        NaN        NaN        NaN
# 2                                NaN        NaN        NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
df['FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION']
# Out:
# 0                                   NaN
# 1                                   NaN
# 2                               Table 1
# 3       NUTRITIVE VALUE FOR (MAIN MEAL)
# 4                             Sr. \nNo.
#                      ...
# 151                                  26
# 152                                  27
# 153                                  28
# 154                                  29
# 155                                  30
# Name: FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION, Length: 156, dtype: object

# %%
df['Unnamed: 1']
# Out:
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                 Name
#                     ...
# 151              Mango (1 Medium Size)
# 152             Chikoo (1 Medium Size)
# 153    Muskmelon Fruit (1 Medium Size)
# 154         Kiwi Fruit (1 Medium Size)
# 155        Pomegranate (1 Medium Size)
# Name: Unnamed: 1, Length: 156, dtype: object

# %%
df.iloc[4:11]
# Out:
#    FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION  \
# 4                                           Sr. \nNo.
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                NaN
#
#                            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 4                                Name   Proteins     Carbls       Fats
# 5   Plain Steamed Rice (1 Small Bowl)       2.61      26.75       0.45
# 6                Roti (1 Medium Size)       3.01      17.45       0.45
# 7              Bhakhri(1 Medium Size)       2.01      18.05       6.05
# 8              Paratha(1 Medium Size)       4.25      23.92       0.65
# 9        Rotla (Bajra)(1 Medium Size)       3.65       21.1       1.67
# ...

# %%
import pandas as pd

def extract_table_info(df, table_name, start_col, end_col):
    table = df.iloc[start_col:end_col]
    print(f"\n{table_name}:")
    print(table)

# %%
# Extract information from each table
df.iloc[18:27]
# Out:
#    FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION  \
# 18                                          Sr. \nNo.
# 19                                                  1
# 20                                                  2
# 21                                                  3
# 22                                                  4
# 23                                                  5
# 24                                                  6
# 25                                                  7
# 26                                                NaN
#
#                                  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 18                                     Name   Proteins     Carbls       Fats
# 19               Red gram dal(1 Small Bowl)       7.25      18.75        1.4
# 20             Green gram dal(1 Small Bowl)      48.35      118.9       2.45
# 21             Horse gram dal(1 Small Bowl)       6.35      16.25       2.95
# ...

# %%
extract_table_info(df, "Table 1", 4, 11)
extract_table_info(df, "Table 2", 13, 16)
extract_table_info(df, "Table 3", 18, 26)
extract_table_info(df, "Table 4", 29, 33)
extract_table_info(df, "Table 5", 36, 41)
extract_table_info(df, "Table 6", 44, 56)
extract_table_info(df, "Table 7", 59, 63)
extract_table_info(df, "Table 8", 66, 71)
extract_table_info(df, "Table 9", 74, 80)
extract_table_info(df, "Table 10", 83, 96)
extract_table_info(df, "Table 11", 99, 105)
extract_table_info(df, "Table 12", 108, 110)
extract_table_info(df, "Table 13", 113, 115)
extract_table_info(df, "Table 14", 118, 122)
extract_table_info(df, "Table 15", 125, 156)
# Out:
# Table 1:
#    FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION  \
# 4                                           Sr. \nNo.
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                NaN
#
#                            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 4                                Name   Proteins     Carbls       Fats
# 5   Plain Steamed Rice (1 Small Bowl)       2.61      26.75       0.45
# 6                Roti (1 Medium Size)       3.01      17.45       0.45
# 7              Bhakhri(1 Medium Size)       2.01      18.05       6.05
# 8              Paratha(1 Medium Size)       4.25      23.92       0.65
# 9        Rotla (Bajra)(1 Medium Size)       3.65       21.1       1.67
# ...

# %%
import pandas as pd

def extract_table_info(df, table_name, start_col, end_col):
    table = df.iloc[start_col:end_col]
    # print(f"\n{table_name}:")
    # print(table)
    return table

# %%
# Extract information from each table
table1 = extract_table_info(df, "Table 1", 3, 11)
table2 = extract_table_info(df, "Table 2", 12, 16)
table3 = extract_table_info(df, "Table 3", 17, 26)
table4 = extract_table_info(df, "Table 4", 28, 33)
table5 = extract_table_info(df, "Table 5", 35, 41)
table6 = extract_table_info(df, "Table 6", 43, 56)
table7 = extract_table_info(df, "Table 7", 58, 63)
table8 = extract_table_info(df, "Table 8", 65, 71)
table9 = extract_table_info(df, "Table 9", 73, 80)
table10 = extract_table_info(df, "Table 10", 82, 96)
table11 = extract_table_info(df, "Table 11", 98, 105)
table12 = extract_table_info(df, "Table 12", 107, 110)
table13 = extract_table_info(df, "Table 13", 112, 115)
table14 = extract_table_info(df, "Table 14", 117, 122)
table15 = extract_table_info(df, "Table 15", 124, 156)

# %%
table1.iloc[:1]['FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION']
# Out:
# 3     NUTRITIVE VALUE FOR (MAIN MEAL)
# Name: FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION, dtype: object

# %%
table2.iloc[:1]['FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION']
# Out:
# 12    NUTRITIVE VALUE FOR (SNACK)
# Name: FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION, dtype: object

# %%
table1
# Out:
#    FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION  \
# 3                     NUTRITIVE VALUE FOR (MAIN MEAL)
# 4                                           Sr. \nNo.
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                NaN
#
#                            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 3                                 NaN        NaN        NaN        NaN
# 4                                Name   Proteins     Carbls       Fats
# 5   Plain Steamed Rice (1 Small Bowl)       2.61      26.75       0.45
# 6                Roti (1 Medium Size)       3.01      17.45       0.45
# 7              Bhakhri(1 Medium Size)       2.01      18.05       6.05
# ...

# %%
table12
# Out:
#     FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION  \
# 107  NUTRITIVE VALUE FOR (CEREAL + PULSE + VEGETABL...
# 108                                          Sr. \nNo.
# 109                                                  1
#
#                            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 107                               NaN        NaN        NaN        NaN
# 108                              Name   Proteins     Carbls       Fats
# 109  VaghareliKhichadi (1 Small Bowl)        3.4       17.2       1.98
#
#     Unnamed: 5 Unnamed: 6   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 107        NaN        NaN          NaN        NaN        NaN         NaN
# 108      Fiber        Cal  Break\nFast      Lunch     Dinner     Summer
# 109       0.98         98            1          1          1           1
#
#     Unnamed: 11 Unnamed: 12
# 107         NaN         NaN
# 108     Winter      Monsoon
# 109           1           1

# %%
table12.iloc[0][0]
# Out:
# /tmp/ipykernel_30290/1679199113.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   table12.iloc[0][0]
# 'NUTRITIVE VALUE FOR (CEREAL + PULSE + VEGETABLE  PRODUCTS) (1 SMALL BOWL)'

# %%
table12.iloc[1]
# Out:
# FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION      Sr. \nNo.
# Unnamed: 1                                                            Name
# Unnamed: 2                                                        Proteins
# Unnamed: 3                                                          Carbls
# Unnamed: 4                                                            Fats
# Unnamed: 5                                                           Fiber
# Unnamed: 6                                                             Cal
# Unnamed: 7                                                     Break\nFast
# Unnamed: 8                                                           Lunch
# Unnamed: 9                                                          Dinner
# Unnamed: 10                                                        Summer
# Unnamed: 11                                                        Winter
# Unnamed: 12                                                        Monsoon
# ...

# %%
df  = table12
# Extract relevant information from the DataFrame and convert it into a dictionary
header_row = 0  # Assuming the header is in row 108

# Extract header information
header = df.iloc[header_row, 0]

# Extract data information
data_dict = {}
for index, row in df.iloc[header_row + 1 :].iterrows():
    food_name = row[1]
    food_info = dict(zip(df.columns[2:], row[2:]))
    data_dict[food_name] = food_info

result_dict = {header: data_dict}

print(result_dict)
# Out:
# {'NUTRITIVE VALUE FOR (CEREAL + PULSE + VEGETABLE  PRODUCTS) (1 SMALL BOWL)': {'Name': {'Unnamed: 2': 'Proteins', 'Unnamed: 3': 'Carbls', 'Unnamed: 4': 'Fats', 'Unnamed: 5': 'Fiber', 'Unnamed: 6': 'Cal', 'Unnamed: 7': 'Break\nFast', 'Unnamed: 8': 'Lunch', 'Unnamed: 9': 'Dinner', 'Unnamed: 10': 'Summer ', 'Unnamed: 11': 'Winter ', 'Unnamed: 12': 'Monsoon'}, 'VaghareliKhichadi (1 Small Bowl)': {'Unnamed: 2': 3.4, 'Unnamed: 3': 17.2, 'Unnamed: 4': 1.98, 'Unnamed: 5': 0.98, 'Unnamed: 6': 98, 'Unnamed: 7': 1, 'Unnamed: 8': 1, 'Unnamed: 9': 1, 'Unnamed: 10': 1, 'Unnamed: 11': 1, 'Unnamed: 12': 1}}}
# /tmp/ipykernel_30290/1526912651.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   food_name = row[1]

# %%
df
# Out:
#     FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION  \
# 107  NUTRITIVE VALUE FOR (CEREAL + PULSE + VEGETABL...
# 108                                          Sr. \nNo.
# 109                                                  1
#
#                            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 107                               NaN        NaN        NaN        NaN
# 108                              Name   Proteins     Carbls       Fats
# 109  VaghareliKhichadi (1 Small Bowl)        3.4       17.2       1.98
#
#     Unnamed: 5 Unnamed: 6   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 107        NaN        NaN          NaN        NaN        NaN         NaN
# 108      Fiber        Cal  Break\nFast      Lunch     Dinner     Summer
# 109       0.98         98            1          1          1           1
#
#     Unnamed: 11 Unnamed: 12
# 107         NaN         NaN
# 108     Winter      Monsoon
# 109           1           1

# %%
table1
# Out:
#    FOOD_ DATA_SET FOR CARDIAC PATIENT \nWITH CAL SPECIFICATION  \
# 3                     NUTRITIVE VALUE FOR (MAIN MEAL)
# 4                                           Sr. \nNo.
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                NaN
#
#                            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 3                                 NaN        NaN        NaN        NaN
# 4                                Name   Proteins     Carbls       Fats
# 5   Plain Steamed Rice (1 Small Bowl)       2.61      26.75       0.45
# 6                Roti (1 Medium Size)       3.01      17.45       0.45
# 7              Bhakhri(1 Medium Size)       2.01      18.05       6.05
# ...

# %%
{"NUTRITIVE VALUE FOR (MAIN MEAL":{"Name": {"Plain Steamed Rice (1 Small Bowl)" ,	2.61 	,26.75 	,0.45 	,0.55 	,120 ,	0 	,1 ,1,1, 	1, 	1 	,1} , }}
# Out:
# {'NUTRITIVE VALUE FOR (MAIN MEAL': {'Name': {0,
#    0.45,
#    0.55,
#    1,
#    120,
#    2.61,
#    26.75,
#    'Plain Steamed Rice (1 Small Bowl)'}}}

# %%
table1.iloc[0][0]
# Out:
# /tmp/ipykernel_30290/4165716902.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   table1.iloc[0][0]
# ' NUTRITIVE VALUE FOR (MAIN MEAL)'

# %%
val
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 val
#
# NameError: name 'val' is not defined

# %%
Info = {}

val = list(table1[table1["Unnamed: 1"].notna()]["Unnamed: 1"].unique())
for i in range(len(val)):
    if i  == 0:
        Info[table1.iloc[0][0]] = {}
    else:
        Info[table1.iloc[0][0]][val[i]] = table1[table1['Unnamed: 1'] == val[i]].values[:,2:]
    
Info
# Out:
# /tmp/ipykernel_30290/649618107.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Info[table1.iloc[0][0]] = {}
# /tmp/ipykernel_30290/649618107.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Info[table1.iloc[0][0]][val[i]] = table1[table1['Unnamed: 1'] == val[i]].values[:,2:]
# {' NUTRITIVE VALUE FOR (MAIN MEAL)': {'Plain Steamed Rice (1 Small Bowl)': array([[2.61, 26.75, 0.45, 0.55, 120, 0, 1, 1, 1, 1, 1]], dtype=object),
#   'Roti (1 Medium Size)': array([[3.01, 17.45, 0.45, 2.75, 85, 1, 1, 1, 1, 1, 1]], dtype=object),
# ...

# %%
Info = {}

# Assuming you have 15 tables named table1, table2, ..., table15
for table_number in range(1, 16):
    current_table_name = f'table{table_number}'
    current_table = globals()[current_table_name]  # Get the table using globals()

    unique_values = current_table[current_table["Unnamed: 1"].notna()]["Unnamed: 1"].unique()

    for i, val in enumerate(unique_values):
        if i == 0:
            Info[current_table.iloc[0][0]] = {}
        else:
            Info[current_table.iloc[0][0]][val] = current_table[current_table['Unnamed: 1'] == val].values[:, 2:]

print(Info)
# Out:
# {' NUTRITIVE VALUE FOR (MAIN MEAL)': {'Plain Steamed Rice (1 Small Bowl)': array([[2.61, 26.75, 0.45, 0.55, 120, 0, 1, 1, 1, 1, 1]], dtype=object), 'Roti (1 Medium Size)': array([[3.01, 17.45, 0.45, 2.75, 85, 1, 1, 1, 1, 1, 1]], dtype=object), 'Bhakhri(1 Medium Size)': array([[2.01, 18.05, 6.05, 1.04, 130, 1, 1, 1, 1, 1, 1]], dtype=object), 'Paratha(1 Medium Size)': array([[4.25, 23.92, 0.65, 3.75, 118, 1, 1, 1, 1, 1, 1]], dtype=object), 'Rotla (Bajra)(1 Medium Size)': array([[3.65, 21.1, 1.67, 3.58, 113, 1, 1, 1, 1, 1, 1]], dtype=object)}, 'NUTRITIVE VALUE FOR (SNACK)': {'Khakhra(1 Pieces) (1 Medium Size)': array([[3.55, 1.85, 3.05, 2.06, 89, 1, 0, 0, 1, 1, 1]], dtype=object)}, 'NUTRITIVE VALUE FOR (MAIN MEAL) DAL & SUBJI (COUNTED THE NUTRITIVE VALUE FOR 1 BOWL)': {'Red gram dal(1 Small Bowl)': array([[7.25, 18.75, 1.4, 3.15, 116, 0, 1, 1, 1, 1, 1]], dtype=object), 'Green gram dal(1 Small Bowl)': array([[48.35, 118.9, 2.45, 16.25, 686, 0, 1, 1, 1, 1, 1]], dtype=object), 'Horse gram 
# ...

# %%
Info
# Out:
# {' NUTRITIVE VALUE FOR (MAIN MEAL)': {'Plain Steamed Rice (1 Small Bowl)': array([[2.61, 26.75, 0.45, 0.55, 120, 0, 1, 1, 1, 1, 1]], dtype=object),
#   'Roti (1 Medium Size)': array([[3.01, 17.45, 0.45, 2.75, 85, 1, 1, 1, 1, 1, 1]], dtype=object),
#   'Bhakhri(1 Medium Size)': array([[2.01, 18.05, 6.05, 1.04, 130, 1, 1, 1, 1, 1, 1]], dtype=object),
#   'Paratha(1 Medium Size)': array([[4.25, 23.92, 0.65, 3.75, 118, 1, 1, 1, 1, 1, 1]], dtype=object),
#   'Rotla (Bajra)(1 Medium Size)': array([[3.65, 21.1, 1.67, 3.58, 113, 1, 1, 1, 1, 1, 1]], dtype=object)},
#  'NUTRITIVE VALUE FOR (SNACK)': {'Khakhra(1 Pieces) (1 Medium Size)': array([[3.55, 1.85, 3.05, 2.06, 89, 1, 0, 0, 1, 1, 1]], dtype=object)},
#  'NUTRITIVE VALUE FOR (MAIN MEAL) DAL & SUBJI (COUNTED THE NUTRITIVE VALUE FOR 1 BOWL)': {'Red gram dal(1 Small Bowl)': array([[7.25, 18.75, 1.4, 3.15, 116, 0, 1, 1, 1, 1, 1]], dtype=object),
# ...

# %%
import pickle 

with open('/workspaces/codespaces-blank/data/food_Info.pkl', 'wb') as f:
    pickle.dump(Info, f)

# %%
with open('/workspaces/codespaces-blank/data/food_Info.pkl', 'rb') as f:
    food_tables = pickle.load(f)

# %%
len(Info.keys())
# Out:
# 15

# %%
import random

# Sample food tables with food names and calories
food_tables = {
    'vegetables': {'Spinach': 23, 'Broccoli': 55, 'Carrots': 41, 'Bell Pepper': 31},
    'fruits': {'Apple': 95, 'Banana': 105, 'Orange': 62, 'Grapes': 69},
    'protein_sources': {'Chicken Breast': 165, 'Salmon': 206, 'Tofu': 144, 'Eggs': 68},
    # Add more tables as needed
}

def recommend_food(calorie_limit):
    selected_foods = []
    remaining_calories = calorie_limit

    while remaining_calories > 0:
        # Choose a random food table
        table_name = random.choice(list(food_tables.keys()))
        table = food_tables[table_name]

        # Choose a random food item from the selected table
        food_name = random.choice(list(table.keys()))
        food_calories = table[food_name]

        # Check if adding the food exceeds the remaining calories
        if remaining_calories - food_calories >= 0:
            selected_foods.append((food_name, food_calories))
            remaining_calories -= food_calories

    return selected_foods

def main():
    # Set the daily calorie limit for the patient
    daily_calorie_limit = 1500

    # Get the recommended foods based on the daily calorie limit
    recommended_foods = recommend_food(daily_calorie_limit)

    # Display the recommended foods
    print("Recommended foods:")
    for food, calories in recommended_foods:
        print(f"{food}: {calories} calories")

if __name__ == "__main__":
    main()

# %%
food_tables = Info

# %%
import random

# %%
table_name = random.choice(list(food_tables.keys()))
table = food_tables[table_name]
table
# Out:
# {'VaghareliKhichadi (1 Small Bowl)': array([[3.4, 17.2, 1.98, 0.98, 98, 1, 1, 1, 1, 1, 1]], dtype=object)}

# %%
list(table.values())[0][0][5]
# Out:
# 1

# %%
# Choose a random food item from the selected table
food_name = random.choice(list(table.keys()))
food_calories = table[food_name]
food_calories[0]
# food_calories[0][4]
# Out:
# array([1.2, 5.98, 0.25, 2.6, 29, 0, 1, 1, 1, 1, 0], dtype=object)

# %%
import random

def recommend_food(calorie_limit):
    selected_foods_breakfast = []
    selected_foods_lunch = []
    selected_foods_dinner = []
    
    remaining_calories_breakfast = int(calorie_limit * 0.4)
    remaining_calories_lunch = int(calorie_limit * 0.3)
    remaining_calories_dinner = int(calorie_limit * 0.3)

    for meal, remaining_calories in [('Breakfast', remaining_calories_breakfast),
                                     ('Lunch', remaining_calories_lunch),
                                     ('Dinner', remaining_calories_dinner)]:

        while remaining_calories > 0:
            # Choose a random food table
            table_name = random.choice(list(food_tables.keys()))
            table = food_tables[table_name]

            # Choose a random food item from the selected table
            food_name = random.choice(list(table.keys()))
            food_calories = table[food_name]

            # Check if adding the food exceeds the remaining calories for the current meal
            if remaining_calories - food_calories >= 0:
                if meal == 'Breakfast':
                    selected_foods_breakfast.append((food_name, food_calories))
                elif meal == 'Lunch':
                    selected_foods_lunch.append((food_name, food_calories))
                elif meal == 'Dinner':
                    selected_foods_dinner.append((food_name, food_calories))

                remaining_calories -= food_calories

    return selected_foods_breakfast, selected_foods_lunch, selected_foods_dinner

# Example usage:
food_tables = {
    'vegetables': {'Spinach': 23, 'Broccoli': 55, 'Carrots': 41, 'Bell Pepper': 31},
    'fruits': {'Apple': 95, 'Banana': 105, 'Orange': 62, 'Grapes': 69},
    'protein_sources': {'Chicken Breast': 165, 'Salmon': 206, 'Tofu': 144, 'Eggs': 68},
    # Add more tables as needed
}

daily_calorie_limit = 100
recommended_foods_breakfast, recommended_foods_lunch, recommended_foods_dinner = recommend_food(daily_calorie_limit)

print("Recommended foods for Breakfast:")
for food, calories in recommended_foods_breakfast:
    print(f"{food}: {calories} calories")

print("\nRecommended foods for Lunch:")
for food, calories in recommended_foods_lunch:
    print(f"{food}: {calories} calories")

print("\nRecommended foods for Dinner:")
for food, calories in recommended_foods_dinner:
    print(f"{food}: {calories} calories")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 47
#      39 food_tables = {
#      40     'vegetables': {'Spinach': 23, 'Broccoli': 55, 'Carrots': 41, 'Bell Pepper': 31},
#      41     'fruits': {'Apple': 95, 'Banana': 105, 'Orange': 62, 'Grapes': 69},
#      42     'protein_sources': {'Chicken Breast': 165, 'Salmon': 206, 'Tofu': 144, 'Eggs': 68},
#      43     # Add more tables as needed
#      44 }
#      46 daily_calorie_limit = 100
# ---> 47 recommended_foods_breakfast, recommended_foods_lunch, recommended_foods_dinner = recommend_food(daily_calorie_limit)
#      49 print("Recommended foods for Breakfast:")
#      50 for food, calories in recommended_foods_breakfast:
#
# Cell In[74], line 26, in recommend_food(calorie_limit)
#      23 food_calories = table[food_name]
# ...
